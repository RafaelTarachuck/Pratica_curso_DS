# %% [markdown]
# Agrupador nçao supervisionado
# Semelhante ao K-means, porém não agrupa de forma absoluta, atribuindo percentuais de aderência as classes para cada os dados.

# %%
pip install scikit-fuzzy
# Out:
# ...
# Using legacy 'setup.py install' for scikit-fuzzy, since package 'wheel' is not installed.
# ...
#     Running setup.py install for scikit-fuzzy: started
#     Running setup.py install for scikit-fuzzy: finished with status 'done'
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\rafae\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
#import das bibliotecas
from sklearn import datasets
import numpy as np
from sklearn.metrics import confusion_matrix
import skfuzzy

# %%
#import do conjunto de dados iris presente na biblioteca Sklearn
iris = datasets.load_iris()

# %%
#
r = skfuzzy.cmeans(data = iris.data.T, c = 3, m = 2, error = 0.005, maxiter = 1000, init = None)

# %%
# obtendo as porcentagens de uma registro pertencente a um cluster que está na posição 1 da matriz retornada
previsoes_porcentagem = r[1]

# %%
#visualização da probabilidade de um registro pertencer a cada um dos clusters
for x in range (150):
    print(previsoes_porcentagem[0][x], previsoes_porcentagem[1][x], previsoes_porcentagem[2][x])
# Out:
# 0.0023044348754539218 0.9966236289081214 0.0010719362164247116
# 0.016658723655622924 0.9758402618565128 0.0075010144878642215
# 0.013765517510027254 0.9798179219694713 0.006416560520501561
# 0.02247726750566598 0.9674111781542574 0.010111554340076502
# 0.003762041097720954 0.9944700632530469 0.0017678956492321993
# 0.04482547747189816 0.9345478407413307 0.020626681786771316
# 0.014010042527649475 0.979483355847908 0.006506601624442401
# 0.0003116988006175807 0.9995470393353687 0.0001412618640138009
# 0.04774116378833158 0.9303488079753028 0.021910028236365606
# 0.011942417781252998 0.98271369397507 0.005343888243676994
# 0.021765227226202857 0.9680308551888029 0.010203917584994273
# 0.005435189445319967 0.9921325633323462 0.0024322472223338434
# 0.0201931527291886 0.970626222776428 0.00918062449438338
# 0.05181504832382587 0.9229417613203652 0.02524319035580891
# 0.0726305811626189 0.8897286622508713 0.03764075658650964
# 0.10437820275063255 0.841302226489154 0.05431957076021342
# ...

# %%
#geração de matriz decontingencia para comparação com as classes originais da base de dados
previsoes = previsoes_porcentagem.argmax(axis = 0)
resultado = confusion_matrix(iris.target, previsoes)
resultado
# Out:
# array([[ 0, 50,  0],
#        [47,  0,  3],
#        [13,  0, 37]], dtype=int64)
